# %% [markdown]
# Accessing DataFrame using Index and slicing

# %%
import pandas as pd
df = pd.read_csv('c:/users/rakesh/desktop/Notes/pandascode/student.csv')
print(df)

# %%
print(df[1]) #since dataframe contains rows and columns

#if you want to retrive the record of only one row then use   iloc() method

df.iloc[1]

# %%
print(df[1:5:2])
# Out:
#     name  english  math  cs  physics  chemistry
# 1   amit       56    89  56       67         87
# 3  vikas       34    67  89       78         67

# %%
print(df['name'])
# Out:
# 0    rakesh
# 1      amit
# 2        jm
# 3     vikas
# 4        rk
# 5     dhruv
# Name: name, dtype: object

# %%
print(df[['name','english']])  # only list of column name is allowed
# Out:
#      name  english
# 0  rakesh       45
# 1    amit       56
# 2      jm       45
# 3   vikas       34
# 4      rk       67
# 5   dhruv       78

# %%
df.iloc[1:4,[1,3,5]]   # iloc() is used to fetch rows or columns using their index values
                       # rows are defined in the form of slicing but columns are defined in the form 
                       # list of index numbers
# Out:
#    english  cs  chemistry
# 1       56  56         87
# 2       45  89         66
# 3       34  89         67

# %%
df
# Out:
#      name  english  math  cs  physics  chemistry
# 0  rakesh       45    87  56       56         78
# 1    amit       56    89  56       67         87
# 2      jm       45    45  89       67         66
# 3   vikas       34    67  89       78         67
# 4      rk       67    89  67       67         45
# 5   dhruv       78    67  90       56         56

# %% [markdown]
# changing DataFrame's Index

# %%
#changing dataFrame's index
df.set_index('name',inplace=True)
df
# Out:
#         english  math  cs  physics  chemistry
# name
# rakesh       45    87  56       56         78
# amit         56    89  56       67         87
# jm           45    45  89       67         66
# vikas        34    67  89       78         67
# rk           67    89  67       67         45
# dhruv        78    67  90       56         56

# %% [markdown]
# Resetting original INdex

# %%
#reseting original index of the dataframe
df.reset_index(inplace=True)
df
# Out:
#      name  english  math  cs  physics  chemistry
# 0  rakesh       45    87  56       56         78
# 1    amit       56    89  56       67         87
# 2      jm       45    45  89       67         66
# 3   vikas       34    67  89       78         67
# 4      rk       67    89  67       67         45
# 5   dhruv       78    67  90       56         56

# %% [markdown]
# Change the name of any column

# %%
#changing all the column names of a DataFrame
df.columns=['Name','Eng','Maths','CompSc','Phy','Chem']
df
# Out:
#      Name  Eng  Maths  CompSc  Phy  Chem
# 0  rakesh   45     87      56   56    78
# 1    amit   56     89      56   67    87
# 2      jm   45     45      89   67    66
# 3   vikas   34     67      89   78    67
# 4      rk   67     89      67   67    45
# 5   dhruv   78     67      90   56    56

# %%
# Below are some quick examples.
# Syntax to change column name using rename() function.
df.rename(columns={"Eng": "English core"})
# Out:
#      Name  English core  Maths  CompSc  Phy  Chem
# 0  rakesh            45     87      56   56    78
# 1    amit            56     89      56   67    87
# 2      jm            45     45      89   67    66
# 3   vikas            34     67      89   78    67
# 4      rk            67     89      67   67    45
# 5   dhruv            78     67      90   56    56

# %%
# Using rename() function.
df.rename(columns={'English Core': 'Eng','Maths':'Mathematics'})
# Out:
#      Name  Eng  Mathematics  CompSc  Phy  Chem
# 0  rakesh   45           87      56   56    78
# 1    amit   56           89      56   67    87
# 2      jm   45           45      89   67    66
# 3   vikas   34           67      89   78    67
# 4      rk   67           89      67   67    45
# 5   dhruv   78           67      90   56    56

# %%
# Using rename() function.
df.rename(columns={'CompSc': 'Computer'}, inplace=True) 
 #inplace does not display results so we have to display it manually
df
# Out:
#      Name  Eng  Maths  Computer  Phy  Chem
# 0  rakesh   45     87        56   56    78
# 1    amit   56     89        56   67    87
# 2      jm   45     45        89   67    66
# 3   vikas   34     67        89   78    67
# 4      rk   67     89        67   67    45
# 5   dhruv   78     67        90   56    56

# %%
# Renaming Multiple columns.  --silently
df.rename({'Name': 'student name', 'Computer': 'IP',
          'Phy': 'Physics'}, axis="columns", inplace=True)
df
# Out:
#   student name  Eng  Maths  IP  Physics  Chem
# 0       rakesh   45     87  56       56    78
# 1         amit   56     89  56       67    87
# 2           jm   45     45  89       67    66
# 3        vikas   34     67  89       78    67
# 4           rk   67     89  67       67    45
# 5        dhruv   78     67  90       56    56

# %%
df.columns.values[0]='course'   # change column name silently and does not display it directly
df
# Out:
#    course  Eng  Maths  IP  Physics  Chem
# 0  rakesh   45     87  56       56    78
# 1    amit   56     89  56       67    87
# 2      jm   45     45  89       67    66
# 3   vikas   34     67  89       78    67
# 4      rk   67     89  67       67    45
# 5   dhruv   78     67  90       56    56

# %% [markdown]
# Adding a New column in any existing DataFrame

# %%
df['music']=[34,45,56,78,78,89]   #add a new column with given values
df
# Out:
#    course  Eng  Maths  IP  Physics  Chem  music
# 0  rakesh   45     87  56       56    78     34
# 1    amit   56     89  56       67    87     45
# 2      jm   45     45  89       67    66     56
# 3   vikas   34     67  89       78    67     78
# 4      rk   67     89  67       67    45     78
# 5   dhruv   78     67  90       56    56     89

# %%
df['music'] =100     #replace the values of existing column if column already exists
df
# Out:
#    course  Eng  Maths  IP  Physics  Chem  music
# 0  rakesh   45     87  56       56    78    100
# 1    amit   56     89  56       67    87    100
# 2      jm   45     45  89       67    66    100
# 3   vikas   34     67  89       78    67    100
# 4      rk   67     89  67       67    45    100
# 5   dhruv   78     67  90       56    56    100

# %%
df['total']=df['Eng']+df['Maths']+df['IP']+df['Physics']+df['Chem']+df['music']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'eng'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [78], line 1
# ----> 1 df['total']=df['eng']+df['Maths']+df['IP']+df['Physics']+df['Chem']+df['music']
#       2 df
#
# File c:\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'eng'
